# %% [markdown]
# # Solutions
#
# 1. Load in the dataset, calling it `drinks_content`, and then briefly explore it, printing out: first 5 rows, last 5 rows, and then all of the data. Find out the dimensions of the data (number of rows and columns) and the column names.

# %%
import pandas as pd
import numpy as np

# %%
drinks_content = pd.read_csv("starbucks_drinkMenu_expanded.csv")
# First 5 rows
drinks_content
# Out:
#                      Beverage_category  \
# 0                               Coffee
# 1                               Coffee
# 2                               Coffee
# 3                               Coffee
# 4              Classic Espresso Drinks
# 5              Classic Espresso Drinks
# 6              Classic Espresso Drinks
# 7              Classic Espresso Drinks
# 8              Classic Espresso Drinks
# 9              Classic Espresso Drinks
# 10             Classic Espresso Drinks
# 11             Classic Espresso Drinks
# 12             Classic Espresso Drinks
# 13             Classic Espresso Drinks
# 14             Classic Espresso Drinks
# 15             Classic Espresso Drinks
# 16             Classic Espresso Drinks
# 17             Classic Espresso Drinks
# 18             Classic Espresso Drinks
# 19             Classic Espresso Drinks
# 20             Classic Espresso Drinks
# 21             Classic Espresso Drinks
# 22             Classic Espresso Drinks
# ...

# %%
# Last 5 rows
drinks_content.tail()
# Out:
#               Beverage_category                                      Beverage  \
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
#           Beverage_prep  Calories  Total Fat (g)  Trans Fat (g)   \
# 237             Soymilk       320            3 2             0.4
# 238    Tall Nonfat Milk       170            0.1             0.1
# 239          Whole Milk       200            3.5             2.0
# 240             Soymilk       180            1.5             0.2
# 241  Grande Nonfat Milk       240            0.1             0.1
#
#      Saturated Fat (g)   Sodium (mg)   Total Carbohydrates (g)   \
# ...

# %%
# Print everything
drinks_content
# Out:
#                      Beverage_category  \
# 0                               Coffee
# 1                               Coffee
# 2                               Coffee
# 3                               Coffee
# 4              Classic Espresso Drinks
# 5              Classic Espresso Drinks
# 6              Classic Espresso Drinks
# 7              Classic Espresso Drinks
# 8              Classic Espresso Drinks
# 9              Classic Espresso Drinks
# 10             Classic Espresso Drinks
# 11             Classic Espresso Drinks
# 12             Classic Espresso Drinks
# 13             Classic Espresso Drinks
# 14             Classic Espresso Drinks
# 15             Classic Espresso Drinks
# 16             Classic Espresso Drinks
# 17             Classic Espresso Drinks
# 18             Classic Espresso Drinks
# 19             Classic Espresso Drinks
# 20             Classic Espresso Drinks
# 21             Classic Espresso Drinks
# 22             Classic Espresso Drinks
# ...

# %%
# Dimensions
drinks_content.shape
# Out:
# (242, 18)

# %%
# Column names
drinks_content.columns
# Out:
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        ' Total Fat (g)', 'Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',
#        ' Total Carbohydrates (g) ', 'Cholesterol (mg)', ' Dietary Fibre (g)',
#        ' Sugars (g)', ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
#        ' Calcium (% DV) ', 'Iron (% DV) ', 'Caffeine (mg)'],
#       dtype='object')

# %% [markdown]
# 2. We're going to be looking at the number of `Calories` in each drink.
# Calculate some quick summary statistics (e.g. the mean, the maximum and minimum).

# %%
# Check the mean
drinks_content["Calories"].mean()
# Out:
# 193.87190082644628

# %%
# Check the min
drinks_content["Calories"].min()
# Out:
# 0

# %%
# Check the max
drinks_content["Calories"].max()
# Out:
# 510

# %% [markdown]
# 3. Select the variables Beverage_category, Beverage, Beverage prep and Calories from the `drinks_content` data frame, and assign the selected columns to a new data frame called `drinks`. Check if there are any missing values anywhere in the data, and drop any rows containing them if there are.

# %%
# Select dataset with specific columns
drinks = drinks_content.loc[:, ["Beverage", "Beverage_category", "Beverage_prep", "Calories"]].copy()

# %%
# Check if there are NA values
drinks.isna().sum()
# Out:
# Beverage             0
# Beverage_category    0
# Beverage_prep        0
# Calories             0
# dtype: int64

# %%
# No missing values so no need to drop them!

# %% [markdown]
# 4. In your `drinks` dataframe create a new variable (column) called `calorie_diff`, which stores the difference between 135 calories (135 calories = 10 cubes of sugar!) and the calories in each drink. (Hint: you’ll want to subtract the calories from 135 to see which drink have more or less than 10 cups of sugar).

# %%
drinks["calorie_diff"] = 135 - drinks["Calories"]
drinks
# Out:
#                                          Beverage  \
# 0                                   Brewed Coffee
# 1                                   Brewed Coffee
# 2                                   Brewed Coffee
# 3                                   Brewed Coffee
# 4                                     Caffè Latte
# 5                                     Caffè Latte
# 6                                     Caffè Latte
# 7                                     Caffè Latte
# 8                                     Caffè Latte
# 9                                     Caffè Latte
# 10                                    Caffè Latte
# 11                                    Caffè Latte
# 12                                    Caffè Latte
# 13                                    Caffè Latte
# 14                                    Caffè Latte
# 15                                    Caffè Latte
# 16            Caffè Mocha (Without Whipped Cream)
# 17            Caffè Mocha (Without Whipped Cream)
# ...

# %% [markdown]
# 5. Summarise the mean number of calories in each `Beverage_category`.

# %%
# method 1
drinks.groupby("Beverage_category")["Calories"].mean()
# Out:
# Beverage_category
# Classic Espresso Drinks              140.172414
# Coffee                                 4.250000
# Frappuccino® Blended Coffee          276.944444
# Frappuccino® Blended Crème           233.076923
# Frappuccino® Light Blended Coffee    162.500000
# Shaken Iced Beverages                114.444444
# Signature Espresso Drinks            250.000000
# Smoothies                            282.222222
# Tazo® Tea Drinks                     177.307692
# Name: Calories, dtype: float64

# %%
# method 2
drinks.groupby("Beverage_category").mean()["Calories"]
# Out:
# Beverage_category
# Classic Espresso Drinks              140.172414
# Coffee                                 4.250000
# Frappuccino® Blended Coffee          276.944444
# Frappuccino® Blended Crème           233.076923
# Frappuccino® Light Blended Coffee    162.500000
# Shaken Iced Beverages                114.444444
# Signature Espresso Drinks            250.000000
# Smoothies                            282.222222
# Tazo® Tea Drinks                     177.307692
# Name: Calories, dtype: float64

# %% [markdown]
# 6. **Harder** - Which `Beverage_prep` type contains more than the average calories of all drinks?
# (Hint: to answer this, you’ll have to first figure out what the average calories across all drinks are, and then use that as a filter for the grouped Beverage_prep data).

# %%
average_cals = drinks["Calories"].mean()
average_cals
# Out:
# 193.87190082644628

# %%
drinks.loc[drinks["Calories"] > average_cals].sort_values("Calories", ascending = False)
# Out:
#                                             Beverage  \
# 84     White Chocolate Mocha (Without Whipped Cream)
# 85     White Chocolate Mocha (Without Whipped Cream)
# 215                Java Chip (Without Whipped Cream)
# 128                            Tazo® Green Tea Latte
# 83     White Chocolate Mocha (Without Whipped Cream)
# 216                Java Chip (Without Whipped Cream)
# 214                Java Chip (Without Whipped Cream)
# 81     White Chocolate Mocha (Without Whipped Cream)
# 129                            Tazo® Green Tea Latte
# 197                    Mocha (Without Whipped Cream)
# 96             Hot Chocolate (Without Whipped Cream)
# 206                  Caramel (Without Whipped Cream)
# 82     White Chocolate Mocha (Without Whipped Cream)
# 127                            Tazo® Green Tea Latte
# 101      Caramel Apple Spice (Without Whipped Cream)
# 188                                           Coffee
# 236     Strawberries & Crème (Without Whipped Cream)
# ...

# %% [markdown]
# 7. **Harder**  - Which is the best type of **coffee drink** to get if you’re worried about consuming too many calories?

# %%
drinks.sort_values("Calories").head(1)
# Out:
#       Beverage Beverage_category Beverage_prep  Calories  calorie_diff
# 102  Tazo® Tea  Tazo® Tea Drinks         Short         0           135

# %% [markdown]
# We see the tea drinks have the lowest calories but the questions specifically asks us about coffee so we want to filter the rows with tea out before arranging.

# %%
drinks.loc[drinks["Beverage_category"] != "Tazo® Tea Drinks"].sort_values("Calories").head(1)
# Out:
#         Beverage Beverage_category Beverage_prep  Calories  calorie_diff
# 0  Brewed Coffee            Coffee         Short         3           132

# %% [markdown]
# 8. Filter the dataset `drinks` so we only take "Classic Espresso Drinks", and save this in a new data frame called `espresso_drinks`.

# %%
# Filter out espresso drinks
espresso_drinks = drinks.loc[drinks["Beverage_category"] == "Classic Espresso Drinks"].copy()
espresso_drinks
# Out:
#                                     Beverage        Beverage_category  \
# 4                                Caffè Latte  Classic Espresso Drinks
# 5                                Caffè Latte  Classic Espresso Drinks
# 6                                Caffè Latte  Classic Espresso Drinks
# 7                                Caffè Latte  Classic Espresso Drinks
# 8                                Caffè Latte  Classic Espresso Drinks
# 9                                Caffè Latte  Classic Espresso Drinks
# 10                               Caffè Latte  Classic Espresso Drinks
# 11                               Caffè Latte  Classic Espresso Drinks
# 12                               Caffè Latte  Classic Espresso Drinks
# 13                               Caffè Latte  Classic Espresso Drinks
# 14                               Caffè Latte  Classic Espresso Drinks
# 15                               Caffè Latte  Classic Espresso Drinks
# ...

# %% [markdown]
# 9. Group your `espresso_drinks` data frame by the type of beverage prep, and then find out the mean calories for each drink group.

# %%
espresso_drinks.groupby("Beverage_prep")["Calories"].mean()
# Out:
# Beverage_prep
# 2% Milk               184.375
# Doppio                 10.000
# Grande                 15.000
# Grande Nonfat Milk    150.000
# Short                   5.000
# Short Nonfat Milk      78.000
# Solo                    5.000
# Soymilk               151.250
# Tall                   10.000
# Tall Nonfat Milk      116.000
# Venti                  25.000
# Venti Nonfat Milk     194.000
# Name: Calories, dtype: float64

# %% [markdown]
# 10. Get the same grouped mean `Calories` values as above, but this time sorted in descending order. (Hint: so you're able to sort the resulting groupby by the 'Calories' column you will want to ensure you get back a dataframe and not a series)

# %%
espresso_drinks.groupby("Beverage_prep")["Calories"].mean().reset_index(name = "avg_cals").sort_values("avg_cals", ascending = False)
# Out:
#          Beverage_prep  avg_cals
# 11   Venti Nonfat Milk   194.000
# 0              2% Milk   184.375
# 7              Soymilk   151.250
# 3   Grande Nonfat Milk   150.000
# 9     Tall Nonfat Milk   116.000
# 5    Short Nonfat Milk    78.000
# 10               Venti    25.000
# 2               Grande    15.000
# 1               Doppio    10.000
# 8                 Tall    10.000
# 4                Short     5.000
# 6                 Solo     5.000
